# %%
import torch
from torch.utils.data import Dataset, DataLoader
from indicnlp.tokenize import indic_tokenize

# %%
file_path = "/home/angkul/my_data/coding/agi/llms/hindi.txt"

with open(file_path, "r", encoding="utf-8") as f:
    raw_text = f.read()

# %%
t1 = ("इस संदर्भ में ब्लम एक सफल नेता के लिए ऐसे कार्य न करने के लिए निर्देश देते हैं। अंत।" 
"जिससे कर्मचारी और नेता के बीच दूरी बनी रहे।")

# %%
# get the unique tokens
# tokens1 = indic_tokenize.trivial_tokenize(t1)

# tokens = sorted(list(set(tokens1)))
# tokens.extend(["अंत"])

tokens = indic_tokenize.trivial_tokenize(raw_text)

tokens = sorted(list(set(tokens)))
tokens.extend(["अंत"])

# %%
print(tokens)
# Out:
# ['\n\n', '\n\nगुरुत्वाकर्षण', '\n\nनेतृत्व', '\n18', '\n1850', '\nअतीत', '\nअधिकारियों', '\nअनेक', '\nअनौपचारिक', '\nअभिजातीय', '\nअर्थात्', '\nआगे', '\nइन', '\nइब्राहीम', '\nइस', '\nइसी', '\nउचित', '\nउदाहरण', '\nउद्योग', '\nउपर्युक्त', '\nएक', '\nओसवाल्ड', '\nकंफ्युशिअसवाद', '\nकर्मचारियों', '\nकारखाने', '\nकार्य', '\nकार्यक्षमता', '\nकुछ', '\nकेप्लर', '\nकैद', '\nकोई', '\nगुरुत्वाकर्षण', '\nछोटे', '\nजर्मन', '\nजिस', '\nतब', '\nतृतीय', '\nद्वितीय', '\nनर', '\nनिरंकुश', '\nनिश्चित', '\nनेता', '\nनेतृत्व', '\nनोअम', '\nपक्षियों', '\nपिंजर', '\nपेट्रीसिया', '\nपॉल', '\nप्रत्येक', '\nप्रथम', '\nप्रागैतिहासिक', '\nप्रारंभिक', '\nप्रेरणा', '\nबोनोबो', '\nब्रूस', '\nब्लम', '\nभारतीय', '\nमाना', '\nमोर', '\nयदि', '\nयह', '\nयहाँ', '\nरिचर्ड', '\nलीलावती', '\nवयस्क', '\nविद्वानों', '\nव्यक्तिगत', '\nसमस्याओं', '\nसामूहिक', '\nसोच', '\nस्मिथ', '\nहाउजर', '\nहालांकि', '!', '"', '%', "'", ',', '-', '.', '/', '0', '100', '100000', '115', '1300', '15', '16', '17', '170', '18', '1800', '1890', '1907', '195', '1970', '2.75', '20', '2000', '2007/07/30/070730fa', '210', '225', '23', '28', '3', '4', '450', '47', '5', '6', '8', '90', '95', ':', '?', 'G', 'Http', 'Leadership', '_', 'books', 'chap1', 'com', 'd', 'f', 'fact', 'htm', 'http', 'longterm', 'm1', 'm2', 'newyorker', 'parker\nसंस्कृत', 'reporting', 'srv', 'style', 'washingtonpost', 'wp', 'www', '{', '}', 'अ', 'अंगुली', 'अंग्रेजी', 'अंडे', 'अंत', 'अंततः', 'अंतर', 'अंतर्गत', 'अंदर', 'अकड़ता', 'अक्ष', 'अक्सर', 'अगर', 'अगस्त', 'अग्रगामी', 'अचानक', 'अचूक', 'अच्छा', 'अच्छी', 'अच्छे', 'अज्ञात', 'अज्ञानता', 'अतिरिक्त', 'अतिवादी', 'अत्यधिक', 'अत्याधिक', 'अथवा', 'अदा', 'अद्भुत', 'अधिक', 'अधिकतम', 'अधिकतर', 'अधिकार', 'अधिकारियों', 'अधिकारी', 'अधिकारों', 'अधीन', 'अधीनता', 'अधीनस्थ', 'अधोमुख', 'अध्यक्ष', 'अध्ययन', 'अध्ययनों', 'अनजाने', 'अनधिकृत', 'अनवस्था', 'अनशन', 'अनाज', 'अनुकूलित', 'अनुकूली', 'अनुचित', 'अनुच्छेद', 'अनुनय', 'अनुपात', 'अनुभव', 'अनुभवजन्य', 'अनुभवी', 'अनुमति', 'अनुमान', 'अनुमानित', 'अनुयायिओं', 'अनुयायियों', 'अनुयायी', 'अनुरक्षण', 'अनुरूप', 'अनुशासन', 'अनुसंधान', 'अनुसरण', 'अनुसार', 'अनूदित', 'अनेक', 'अनौपचारिक', 'अन्त', 'अन्तर्गत', 'अन्तर्दृष्टि', 'अन्य', 'अन्यजानवरों', 'अपना', 'अपनाना', 'अपनाया', 'अपनी', 'अपने', 'अपनेपन', 'अपरिवर्तित', 'अपर्याप्त', 'अपितु', 'अपेक्षाओं', 'अप्रकट', 'अप्रैल', 'अब', 'अब्बोत्त', 'अभाव', 'अभिजात', 'अभियान', 'अभी', 'अभ्यासकर्ता', 'अमेरिकी', 'अमोत्ज़', 'अरस्तू', 'अराजकतावादी', 'अर्गुस', 'अर्थ', 'अर्थात', 'अर्थात्', 'अर्द्ध', 'अर्द्धचन्द्राकार', 'अर्ध', 'अर्धचन्द्राकार', 'अर्ल', 'अलंकरण', 'अलंकृत', 'अलक्ष्य', 'अलग', 'अलबर्ट', 'अलार्म', 'अलावा', 'अलेक्जेंडर', 'अल्फा', 'अवधारणा', 'अवसर', 'अवस्था', 'अवस्थाओं', 'अवहेलना', 'अवैध', 'अव्यक्तिगत', 'अव्यवस्था', 'अव्यापारिक', 'असंतुलन', 'असफल', 'असमय', 'असाधारण', 'असामान्य', 'असुरक्षित', 'अस्तित्व', 'अस्थायी', 'अस्थिर', 'अहंकारी', 'अहम', 'आ', 'आँख', 'आँखें', 'आंकड़े', 'आंकिक', 'आंख', 'आंखें', 'आंखो', 'आंखों', 'आइंस्टाइन', 'आइजक', 'आइज़क', 'आए', 'आएगी', 'आकर्षण', 'आकर्षित', 'आकस्मिक', 'आकार', 'आकाश', 'आकृति', 'आकृष्ट', 'आग', 'आगे', 'आज्ञा', 'आज्ञाएं', 'आडंबरपूर्ण', 'आतंरिक', 'आता', 'आती', 'आते', 'आदमी', 'आदर्श', 'आदान', 'आदि', 'आदेशों', 'आधार', 'आधारित', 'आधुनिक', 'आधे', 'आना', 'आनुवंशिक', 'आने', 'आप', 'आपसी', 'आपात', 'आभास', 'आम', 'आमंत्रित', 'आमतौर', 'आया', 'आयाम', 'आयामों', 'आयुर्वेद', 'आयोजन', 'आरंभ', 'आर्थिक', 'आला', 'आलोचना', 'आवश्यक', 'आवश्यकता', 'आवश्यकताओं', 'आवाज', 'आवाजें', 'आविष्कार', 'आवेदन', 'आश्चर्यजनक', 'आसपास', 'आसा', 'आसानी', 'आसीन', 'आस्तित्वहीन', 'इंडियन', 'इंद्रधनुषी', 'इकाई', 'इच्छा', 'इच्छाएं', 'इच्छानुसार', 'इटली', 'इतना', 'इतनी', 'इतने', 'इतिहास', 'इन', 'इनकी', 'इनके', 'इनक्लीइन', 'इनमें', 'इन्हीं', 'इन्हें', 'इमारतों', 'इलाज', 'इस', 'इसका', 'इसकी', 'इसके', 'इसलिए', 'इससे', 'इसी', 'इसे', 'इस्तेमाल', 'ईगल', 'ईमानदार', 'ईमानदारी', 'ईरोक़ुओइअन', 'ईसा', 'उचित', 'उच्च', 'उजागर', 'उठा', 'उठाकर', 'उठी', 'उठे', 'उड़', 'उड़ान', 'उतना', 'उत्तर', 'उत्तरदायित्व', 'उत्तरदायी', 'उत्तरी', 'उत्तेजित', 'उत्पन्न', 'उत्परिवर्तन', 'उत्पाद', 'उत्पादन', 'उत्पीड़न', 'उत्साहित', 'उथला', 'उदार', 'उदाहरण', 'उद्दीप्त', ...

# %%
vocab = {token:integer for integer, token in enumerate(tokens)}

# %%
print(vocab)
# Out:
# {'\n\n': 0, '\n\nगुरुत्वाकर्षण': 1, '\n\nनेतृत्व': 2, '\n18': 3, '\n1850': 4, '\nअतीत': 5, '\nअधिकारियों': 6, '\nअनेक': 7, '\nअनौपचारिक': 8, '\nअभिजातीय': 9, '\nअर्थात्': 10, '\nआगे': 11, '\nइन': 12, '\nइब्राहीम': 13, '\nइस': 14, '\nइसी': 15, '\nउचित': 16, '\nउदाहरण': 17, '\nउद्योग': 18, '\nउपर्युक्त': 19, '\nएक': 20, '\nओसवाल्ड': 21, '\nकंफ्युशिअसवाद': 22, '\nकर्मचारियों': 23, '\nकारखाने': 24, '\nकार्य': 25, '\nकार्यक्षमता': 26, '\nकुछ': 27, '\nकेप्लर': 28, '\nकैद': 29, '\nकोई': 30, '\nगुरुत्वाकर्षण': 31, '\nछोटे': 32, '\nजर्मन': 33, '\nजिस': 34, '\nतब': 35, '\nतृतीय': 36, '\nद्वितीय': 37, '\nनर': 38, '\nनिरंकुश': 39, '\nनिश्चित': 40, '\nनेता': 41, '\nनेतृत्व': 42, '\nनोअम': 43, '\nपक्षियों': 44, '\nपिंजर': 45, '\nपेट्रीसिया': 46, '\nपॉल': 47, '\nप्रत्येक': 48, '\nप्रथम': 49, '\nप्रागैतिहासिक': 50, '\nप्रारंभिक': 51, '\nप्रेरणा': 52, '\nबोनोबो': 53, '\nब्रूस': 54, '\nब्लम': 55, '\nभारतीय': 56, '\nमाना': 57, '\nमोर': 58, '\nयदि': 59, '\nयह': 60, '\nयहाँ': 61, '\nरिचर्ड': 62, '\nलीलावती': 63, '\nवयस्क': 64, '\nविद्वानों': 65, '\nव्यक्तिगत': 66, '\nसमस्याओं': 67, '\nसामूहिक': 68, '\nसोच': 69, '\nस्मिथ': 70, '\nहाउजर': 71, '\nहालांकि': 72, '!': 73, '"': 74, '%': 75, "'": 76, ',': 77, '-': 78, '.': 79, '/': 80, '0': 81, '100': 82, '100000': 83, '115': 84, '1300': 85, '15': 86, '16': 87, '17': 88, '170': 89, '18': 90, '1800': 91, '1890': 92, '1907': 93, '195': 94, '1970': 95, '2.75': 96, '20': 97, '2000': 98, '2007/07/30/070730fa': 99, '210': 100, '225': 101, '23': 102, '28': 103, '3': 104, '4': 105, '450': 106, '47': 107, '5': 108, '6': 109, '8': 110, '90': 111, '95': 112, ':': 113, '?': 114, 'G': 115, 'Http': 116, 'Leadership': 117, '_': 118, 'books': 119, 'chap1': 120, 'com': 121, 'd': 122, 'f': 123, 'fact': 124, 'htm': 125, 'http': 126, 'longterm': 127, 'm1': 128, 'm2': 129, 'newyorker': 130, 'parker\nसंस्कृत': 131, 'reporting': 132, 'srv': 133, 'style': 134, 'washingtonpost': 135, 'wp': 136, 'www': 137, '{': 138, '}': 139, 'अ': 140, 'अंगुली': 141, 'अंग्रेजी': 142, 'अंडे': 143, 'अंत': 2254, 'अंततः': 145, 'अंतर': 146, 'अंतर्गत': 147, 'अंदर': 148, 'अकड़ता': 149, 'अक्ष': 150, 'अक्सर': 151, 'अगर': 152, 'अगस्त': 153, 'अग्रगामी': 154, 'अचानक': 155, 'अचूक': 156, 'अच्छा': 157, 'अच्छी': 158, 'अच्छे': 159, 'अज्ञात': 160, 'अज्ञानता': 161, 'अतिरिक्त': 162, 'अतिवादी': 163, 'अत्यधिक': 164, 'अत्याधिक': 165, 'अथवा': 166, 'अदा': 167, 'अद्भुत': 168, 'अधिक': 169, 'अधिकतम': 170, 'अधिकतर': 171, 'अधिकार': 172, 'अधिकारियों': 173, 'अधिकारी': 174, 'अधिकारों': 175, 'अधीन': 176, 'अधीनता': 177, 'अधीनस्थ': 178, 'अधोमुख': 179, 'अध्यक्ष': 180, 'अध्ययन': 181, 'अध्ययनों': 182, 'अनजाने': 183, 'अनधिकृत': 184, 'अनवस्था': 185, 'अनशन': 186, 'अनाज': 187, 'अनुकूलित': 188, 'अनुकूली': 189, 'अनुचित': 190, 'अनुच्छेद': 191, 'अनुनय': 192, 'अनुपात': 193, 'अनुभव': 194, 'अनुभवजन्य': 195, 'अनुभवी': 196, 'अनुमति': 197, 'अनुमान': 198, 'अनुमानित': 199, 'अनुयायिओं': 200, 'अनुयायियों': 201, 'अनुयायी': 202, 'अनुरक्षण': 203, 'अनुरूप': 204, 'अनुशासन': 205, 'अनुसंधान': 206, 'अनुसरण': 207, 'अनुसार': 208, 'अनूदित': 209, 'अनेक': 210, 'अनौपचारिक': 211, 'अन्त': 212, 'अन्तर्गत': 213, 'अन्तर्दृष्टि': 214, 'अन्य': 215, 'अन्यजानवरों': 216, 'अपना': 217, 'अपनाना': 218, 'अपनाया': 219, 'अपनी': 220, 'अपने': 221, 'अपनेपन': 222, 'अपरिवर्तित': 223, 'अपर्याप्त': 224, 'अपितु': 225, 'अपेक्षाओं': 226, 'अप्रकट': 227, 'अप्रैल': 228, 'अब': 229, 'अब्बोत्त': 230, 'अभाव': 231, 'अभिजात': 232, 'अभियान': 233, 'अभी': 234, 'अभ्यासकर्ता': 235, 'अमेरिकी': 236, 'अमोत्ज़': 237, 'अरस्तू': 238, 'अराजकतावादी': 239, 'अर्गुस': 240, 'अर्थ': 241, 'अर्थात': 242, 'अर्थात्': 243, 'अर्द्ध': 244, 'अर्द्धचन्द्राकार': 245, 'अर्ध': 246, 'अर्धचन्द्राकार': 247, 'अर्ल': 248, 'अलंकरण': 249, 'अलंकृत': 250, 'अलक्ष्य': 251, 'अलग': 252, 'अलबर्ट': 253, 'अलार्म': 254, 'अलावा': 255, 'अलेक्जेंडर': 256, 'अल्फा': 257, 'अवधारणा': 258, 'अवसर': 259, 'अवस्था': 260, 'अवस्थाओं': 261, 'अवहेलना': 262, 'अवैध': 263, 'अव्यक्तिगत': 264, 'अव्यवस्था': 265, 'अव्यापारिक': 266, 'असंतुलन': 267, 'असफल': 268, 'असमय': 269, 'असाधारण': 270, 'असामान्य': 271, 'असुरक्षित': 2 ...

# %%
print(len(vocab))
# Out:
# 2254

# %%
class hindiTokenizer:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {i:s for s, i in vocab.items()}

    def encode(self, text):
        preproccessed = indic_tokenize.trivial_tokenize(text)
        preproccessed = [item.strip() for item in preproccessed if item.strip()]
        preproccessed = [item if item in self.str_to_int
                         else "अंत" for item in preproccessed]

        ids = [self.str_to_int[s] for s in preproccessed]
        return ids
    
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        return text

# %%
to = hindiTokenizer(vocab)

# %%
to1 = "जिससे कर्मचारी और नेता के बीच दूरी बनी रहे।अनंत"
to.encode(to1)
# Out:
# [859, 540, 494, 1146, 605, 1488, 1008, 1450, 1711, 2248, 2254]

# %%
to.decode(to.encode(to1))
# Out:
# 'जिससे कर्मचारी और नेता के बीच दूरी बनी रहे । अंत'

# %%
class hindiDataset:
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        token_ids = tokenizer.encode(txt)

        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i: i+max_length]
            target_chunk = token_ids[i+1: i+max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)
    
    def __getitem__(self, index):
        return self.input_ids[index], self.target_ids[index]

# %%
def create_dataloader_v1(txt, batch_size, max_length, stride, shuffle=True, drop_last = True, num_workers=0):

    tokenizer = to

    dataset = hindiDataset(txt, tokenizer, max_length, stride)

    dataloader = DataLoader(
        dataset, batch_size, shuffle, drop_last=drop_last, num_workers=num_workers
    )

    return dataloader

# %%
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=2, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# [tensor([[1525, 1655, 1670, 1141]]), tensor([[1655, 1670, 1141, 1655]])]

# %%
inputs1, targets1 = next(data_iter)
print("Input: ", inputs1)
print("Target: ", targets1)
# Out:
# Input:  tensor([[1670, 1141, 1655,  965]])
# Target:  tensor([[1141, 1655,  965,  478]])

# %%
vocab_size = 2254
output_dim = 256
context_length = 1024

# %%
token_embedding_layer = torch.nn.Embedding(vocab_size, output_dim)
pos_embedding_layer = torch.nn.Embedding(context_length, output_dim)

# %%
max_length = 4
dataloader = create_dataloader_v1(
    raw_text, batch_size=8, max_length=4, stride=4, shuffle=False
)

data_iter = iter(dataloader)
inputs, targets = next(data_iter)
print("Input: ", inputs)
print("Target: ", targets)
print("Input shape: ", inputs.shape)
# Out:
# Input:  tensor([[1525, 1655, 1670, 1141],
#         [1655,  965,  478,  605],
#         [1040,  937, 1200,  555],
#         [ 467, 1420,  494,  734],
#         [1685,  555, 1166, 2233],
#         [  77, 1001,  605,  215],
#         [1522, 1647, 1665,  244],
#         [  78,  800,  605, 1730]])
# Target:  tensor([[1655, 1670, 1141, 1655],
#         [ 965,  478,  605, 1040],
#         [ 937, 1200,  555,  467],
#         [1420,  494,  734, 1685],
#         [ 555, 1166, 2233,   77],
#         [1001,  605,  215, 1522],
#         [1647, 1665,  244,   78],
#         [ 800,  605, 1730, 1647]])
# Input shape:  torch.Size([8, 4])

# %%
token_embeddings = token_embedding_layer(inputs)
print(token_embeddings.shape)
# Out:
# torch.Size([8, 4, 256])

# %%
print(token_embeddings)
# Out:
# tensor([[[-1.4306, -1.0675, -0.2656,  ...,  0.0078, -2.9192,  1.4365],
#          [ 2.0001,  0.2721, -0.8617,  ..., -1.4836, -0.1131,  0.4732],
#          [ 0.8345, -0.9418,  0.8504,  ..., -0.4415,  0.1979,  1.1358],
#          [-0.3314,  0.7942,  1.7510,  ...,  1.0738,  0.2079,  0.9983]],
#
#         [[ 2.0001,  0.2721, -0.8617,  ..., -1.4836, -0.1131,  0.4732],
#          [-0.3432,  0.7745,  0.6078,  ...,  0.5217, -0.5309, -0.0543],
#          [-0.0109, -1.0853, -0.6166,  ..., -1.1420, -2.6438,  0.5352],
#          [ 1.1050, -1.1989, -2.2794,  ...,  0.8033, -1.0606,  0.5993]],
#
#         [[-0.9078,  1.3736,  0.7721,  ...,  0.9173, -1.0332,  0.4758],
#          [-0.7471, -0.9954,  0.8860,  ...,  1.0148, -0.2438,  0.3308],
#          [ 0.1225, -0.5613,  1.0978,  ...,  0.1773,  0.5645,  0.0490],
#          [ 1.0105,  0.1749, -1.8779,  ..., -1.1783,  1.3749,  0.7687]],
#
#         ...,
#
#         [[ 0.3575,  0.8783,  1.6736,  ..., -0.4682,  0.5519, -0.6969],
#          [-0.6814, -1.2627, -0.0612,  ...,  0.8053, -0.1841, -1.3877],
#          [ 1.1050, -1.1989, -2.2794,  ...,  0.8033, -1.0606,  0.5993],
#          [-0.2417, -0.4504, -0.4359,  ...,  0.3079, -1.0182,  2.0007]],
#
#         [[-0.1926, -2.5811, -1.9530,  ...,  0.0866, -0.3816, -0.8781],
#          [ 0.7075,  0.9238, -1.5401,  ..., -1.5380, -1.2013, -0.5889],
#          [ 0.1794, -1.6077,  0.5086,  ...,  0.4329, -1.0771, -1.2903],
#          [-1.0952, -0.1641, -1.0363,  ...,  0.4020,  1.1386, -0.4766]],
#
#         [[-0.7767, -2.2773, -0.1629,  ..., -0.7428, -0.1364, -0.5802],
#          [-0.2352, -0.7209, -1.4745,  ...,  1.1486,  0.0493, -0.5434],
#          [ 1.1050, -1.1989, -2.2794,  ...,  0.8033, -1.0606,  0.5993],
#          [ 1.8997, -0.2979,  0.8330,  ...,  2.1651, -0.0667, -1.0181]]],
#        grad_fn=<EmbeddingBackward0>)
